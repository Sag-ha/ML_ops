# %%
# After installing pip install yfinance pandas
import yfinance as yf

# AAPL -- Apple
# MSFT --- Microsoft
# GOOGL --- Alphabet (Google)
# AMZN → Amazon
# META  Meta (Facebook)
# TSLA → Tesla
#INFLX + Netf11x
# NVDA → NVIDIA

comp = "AAPL"
data = yf.Ticker(comp)
df = data.history(start="2019-01-01", end="2023-01-01")

print(df.head())
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2019-01-02 00:00:00-05:00  36.784142  37.724587  36.627401  37.503723
# 2019-01-03 00:00:00-05:00  34.193183  34.606410  33.722963  33.768085
# 2019-01-04 00:00:00-05:00  34.323794  35.278487  34.150430  35.209614
# 2019-01-07 00:00:00-05:00  35.314110  35.344984  34.649149  35.131245
# 2019-01-08 00:00:00-05:00  35.518360  36.055080  35.271376  35.800968
#
#                               Volume  Dividends  Stock Splits
# Date
# 2019-01-02 00:00:00-05:00  148158800        0.0           0.0
# 2019-01-03 00:00:00-05:00  365248800        0.0           0.0
# 2019-01-04 00:00:00-05:00  234428400        0.0           0.0
# 2019-01-07 00:00:00-05:00  219111200        0.0           0.0
# 2019-01-08 00:00:00-05:00  164101200        0.0           0.0
